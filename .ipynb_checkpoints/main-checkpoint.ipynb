# %%
from diagrams import Cluster, Diagram, Edge
from diagrams.custom import Custom
from diagrams.programming.framework import Angular
from diagrams.onprem.database import Mongodb

with Diagram(name="Abair ecosystem", show=False, direction='LR') as diag:
    
    with Cluster(""):
        database = Mongodb("MongoDB")
        scealai = Custom("", "./icons/scealai.png")
         
        with Cluster("Node"):
            frontend = Angular("frontend")
            
            with Cluster("Express"):
                express = Custom("Express", "./icons/express.png")
            
        
        express >> frontend
        database >> express
        
#     with Custer("Speech Sythesis"):
        
        

diag
